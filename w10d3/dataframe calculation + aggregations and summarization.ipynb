# %%
import pandas as pd

# %%
df = pd.read_csv('../animals.csv')

# %%
df
# Out:
#     brainwt   bodywt           animal
# 0     3.385   44.500       Arctic_fox
# 1     0.480   15.499       Owl_monkey
# 2     1.350    8.100           Beaver
# 3   464.983  423.012              Cow
# 4    36.328  119.498        Gray_wolf
# ..      ...      ...              ...
# 57  160.004  169.000  Brazilian_tapir
# 58    0.900    2.600           Tenrec
# 59    1.620   11.400        Phalanger
# 60    0.104    2.500       Tree_shrew
# 61    4.235   50.400          Red_fox
#
# [62 rows x 3 columns]

# %%
df['bodywt']
# Out:
# 0      44.500
# 1      15.499
# 2       8.100
# 3     423.012
# 4     119.498
#        ...
# 57    169.000
# 58      2.600
# 59     11.400
# 60      2.500
# 61     50.400
# Name: bodywt, Length: 62, dtype: float64

# %%
df[['bodywt']]
# Out:
#      bodywt
# 0    44.500
# 1    15.499
# 2     8.100
# 3   423.012
# 4   119.498
# ..      ...
# 57  169.000
# 58    2.600
# 59   11.400
# 60    2.500
# 61   50.400
#
# [62 rows x 1 columns]

# %%
df['bodywtkg'] = df['bodywt'] * 0.45359237

# %%
df
# Out:
#     brainwt   bodywt           animal    bodywtkg
# 0     3.385   44.500       Arctic_fox   20.184860
# 1     0.480   15.499       Owl_monkey    7.030228
# 2     1.350    8.100           Beaver    3.674098
# 3   464.983  423.012              Cow  191.875016
# 4    36.328  119.498        Gray_wolf   54.203381
# ..      ...      ...              ...         ...
# 57  160.004  169.000  Brazilian_tapir   76.657111
# 58    0.900    2.600           Tenrec    1.179340
# 59    1.620   11.400        Phalanger    5.170953
# 60    0.104    2.500       Tree_shrew    1.133981
# 61    4.235   50.400          Red_fox   22.861055
#
# [62 rows x 4 columns]

# %%
df['wtratio'] = df['bodywt'] / df['brainwt']

# %%
df
# Out:
#     brainwt   bodywt           animal    bodywtkg    wtratio
# 0     3.385   44.500       Arctic_fox   20.184860  13.146233
# 1     0.480   15.499       Owl_monkey    7.030228  32.289583
# 2     1.350    8.100           Beaver    3.674098   6.000000
# 3   464.983  423.012              Cow  191.875016   0.909736
# 4    36.328  119.498        Gray_wolf   54.203381   3.289419
# ..      ...      ...              ...         ...        ...
# 57  160.004  169.000  Brazilian_tapir   76.657111   1.056224
# 58    0.900    2.600           Tenrec    1.179340   2.888889
# 59    1.620   11.400        Phalanger    5.170953   7.037037
# 60    0.104    2.500       Tree_shrew    1.133981  24.038462
# 61    4.235   50.400          Red_fox   22.861055  11.900826
#
# [62 rows x 5 columns]

# %%
import numpy as np

# %%
# np.where(<array != 0>, <valeur retournée si vrai>, <valeur retournée si faux>)

# %%
df['wtratio'] = np.where(df['brainwt'] != 0,
                         df['bodywt'] / df['brainwt'],
                         0)

# %%
df
# Out:
#     brainwt   bodywt           animal    wtratio
# 0     3.385   44.500       Arctic_fox  13.146233
# 1     0.480   15.499       Owl_monkey  32.289583
# 2     1.350    8.100           Beaver   6.000000
# 3   464.983  423.012              Cow   0.909736
# 4    36.328  119.498        Gray_wolf   3.289419
# ..      ...      ...              ...        ...
# 57  160.004  169.000  Brazilian_tapir   1.056224
# 58    0.900    2.600           Tenrec   2.888889
# 59    1.620   11.400        Phalanger   7.037037
# 60    0.104    2.500       Tree_shrew  24.038462
# 61    4.235   50.400          Red_fox  11.900826
#
# [62 rows x 4 columns]

# %%
df['sum'] = df.sum(axis=1)

# %%
df
# Out:
#     brainwt   bodywt           animal    wtratio         sum
# 0     3.385   44.500       Arctic_fox  13.146233   61.031233
# 1     0.480   15.499       Owl_monkey  32.289583   48.268583
# 2     1.350    8.100           Beaver   6.000000   15.450000
# 3   464.983  423.012              Cow   0.909736  888.904736
# 4    36.328  119.498        Gray_wolf   3.289419  159.115419
# ..      ...      ...              ...        ...         ...
# 57  160.004  169.000  Brazilian_tapir   1.056224  330.060224
# 58    0.900    2.600           Tenrec   2.888889    6.388889
# 59    1.620   11.400        Phalanger   7.037037   20.057037
# 60    0.104    2.500       Tree_shrew  24.038462   26.642462
# 61    4.235   50.400          Red_fox  11.900826   66.535826
#
# [62 rows x 5 columns]

# %%
vehicles = pd.read_csv('../vehicles/vehicles.csv')

# %%
vehicles
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
vehicles.groupby(['Transmission'])

# %%
vehicles.groupby(['Transmission'])[['Highway MPG', 'City MPG', 'Combined MPG']].mean()
# Out:
#                                   Highway MPG   City MPG  Combined MPG
# Transmission
# Auto (AV)                           40.000000  35.000000     37.000000
# Auto (AV-S6)                        25.000000  22.000000     23.000000
# Auto (AV-S8)                        22.000000  20.000000     21.000000
# Auto(A1)                            37.000000  41.000000     39.000000
# Auto(AM-S6)                         32.978261  24.315217     27.554348
# Auto(AM-S7)                         25.300781  17.746094     20.425781
# Auto(AM-S8)                         32.000000  23.666667     26.666667
# Auto(AM-S9)                         22.000000  21.000000     21.000000
# Auto(AM5)                           39.000000  33.666667     36.000000
# Auto(AM6)                           31.345455  23.909091     26.736364
# Auto(AM7)                           22.382166  16.248408     18.420382
# Auto(AM8)                           28.600000  22.400000     24.600000
# ...

# %%
vehicles.groupby(['Transmission'])[['Highway MPG', 'City MPG', 'Combined MPG']].median()
# Out:
#                                   Highway MPG  City MPG  Combined MPG
# Transmission
# Auto (AV)                                40.0      35.0          37.0
# Auto (AV-S6)                             25.0      22.0          23.0
# Auto (AV-S8)                             22.0      20.0          21.0
# Auto(A1)                                 37.0      41.0          39.0
# Auto(AM-S6)                              31.0      23.0          26.0
# Auto(AM-S7)                              25.0      17.0          21.0
# Auto(AM-S8)                              32.0      23.5          26.5
# Auto(AM-S9)                              22.0      21.0          21.0
# Auto(AM5)                                38.0      34.0          36.0
# Auto(AM6)                                36.5      27.0          31.0
# Auto(AM7)                                19.0      14.0          16.0
# Auto(AM8)                                24.0      21.0          22.0
# ...

# %%
from scipy import stats
 
def agg_mode(x):
    return(stats.mode(x)[0])

# %%
a = np.array([[6, 8, 3, 0],
              [3, 2, 1, 7],
              [8, 1, 8, 4],
              [5, 3, 0, 5],
              [4, 7, 5, 9]])
stats.mode(a)
# Out:
# ModeResult(mode=array([[3, 1, 0, 0]]), count=array([[1, 1, 1, 1]]))

# %%
stats.mode(a)[0]
# Out:
# array([[3, 1, 0, 0]])

# %%
stats.mode(a)[1]
# Out:
# array([[1, 1, 1, 1]])

# %%
stats.mode(a, axis=None)
# Out:
# ModeResult(mode=array([3]), count=array([3]))

# %%
vehicles.groupby("Transmission")["Vehicle Class"].agg(agg_mode)
# Out:
# Transmission
# Auto (AV)                                                 Compact Cars
# Auto (AV-S6)                                              Compact Cars
# Auto (AV-S8)                                              Midsize Cars
# Auto(A1)                                               Subcompact Cars
# Auto(AM-S6)                                               Compact Cars
# Auto(AM-S7)                                           Minicompact Cars
# Auto(AM-S8)                                               Compact Cars
# Auto(AM-S9)                                                Two Seaters
# Auto(AM5)                                                  Two Seaters
# Auto(AM6)                                                 Compact Cars
# Auto(AM7)                                                  Two Seaters
# Auto(AM8)                           Standard Sport Utility Vehicle 4WD
# Auto(AV-S6)                                               Midsize Cars
# ...

# %%
employees = pd.read_csv('../employees.csv')

# %%
employees
# Out:
#      employ_id first_name last_name     email  phone_number   hire_date  \
# 0          100     Steven      King     SKING  515.123.4567  2003-06-17
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  2006-01-03
# 4          104      Bruce     Ernst    BERNST  590.423.4568  2007-05-21
# ..         ...        ...       ...       ...           ...         ...
# 102        202        Pat       Fay      PFAY  603.123.6666  2005-08-17
# 103        203      Susan    Mavris   SMAVRIS  515.123.7777  2002-06-07
# 104        204    Hermann      Baer     HBAER  515.123.8888  2002-06-07
# 105        205    Shelley   Higgins  SHIGGINS  515.123.8080  2002-06-07
# 106        206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
#
#          job_id  salary  commission_pct  manager_id  department_id
# ...

# %%
employees['hire_date'].str.extract(r'(?P<year>\d\d\d\d)-(?P<month>\d\d)-(?P<day>\d\d)')
# Out:
#      year month day
# 0    2003    06  17
# 1    2005    09  21
# 2    2001    01  13
# 3    2006    01  03
# 4    2007    05  21
# ..    ...   ...  ..
# 102  2005    08  17
# 103  2002    06  07
# 104  2002    06  07
# 105  2002    06  07
# 106  2002    06  07
#
# [107 rows x 3 columns]

# %%
pd.concat([employees, employees['hire_date'].str.extract(r'(?P<year>\d\d\d\d)-(?P<month>\d\d)-(?P<day>\d\d)')], axis=1)
# Out:
#      employ_id first_name last_name     email  phone_number   hire_date  \
# 0          100     Steven      King     SKING  515.123.4567  2003-06-17
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  2006-01-03
# 4          104      Bruce     Ernst    BERNST  590.423.4568  2007-05-21
# ..         ...        ...       ...       ...           ...         ...
# 102        202        Pat       Fay      PFAY  603.123.6666  2005-08-17
# 103        203      Susan    Mavris   SMAVRIS  515.123.7777  2002-06-07
# 104        204    Hermann      Baer     HBAER  515.123.8888  2002-06-07
# 105        205    Shelley   Higgins  SHIGGINS  515.123.8080  2002-06-07
# 106        206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
#
#          job_id  salary  commission_pct  manager_id  department_id  year  \
# ...

# %%
def maxminrange(x):
    return x.max() - x.min()

# %%
employees.groupby('department_id')['salary'].agg(maxminrange)
# Out:
# department_id
# 10.0        0
# 20.0     7000
# 30.0     8500
# 40.0        0
# 50.0     6100
# 60.0     4800
# 70.0        0
# 80.0     7900
# 90.0     7000
# 100.0    5100
# 110.0    3700
# Name: salary, dtype: int64

# %%
pokemon = pd.read_csv('../pokemon.csv')

# %%
pokemon.loc[pokemon['Name'].str.contains('Mega'), 'Name'] = pokemon.loc[pokemon['Name'].str.contains('Mega')]['Name'].str.extract(r'(Mega \w*)')

# %%
pokemon.loc[pokemon['Name'].str.contains('Mega')]['Name'].str.extract(r'(Mega \w*)')
# Out:
#                    0
# 3      Mega Venusaur
# 7     Mega Charizard
# 8     Mega Charizard
# 12    Mega Blastoise
# 19     Mega Beedrill
# 23      Mega Pidgeot
# 71     Mega Alakazam
# 87      Mega Slowbro
# 102      Mega Gengar
# 124  Mega Kangaskhan
# 137      Mega Pinsir
# 141    Mega Gyarados
# 154  Mega Aerodactyl
# 163      Mega Mewtwo
# 164      Mega Mewtwo
# 168              NaN
# 196    Mega Ampharos
# 224     Mega Steelix
# 229      Mega Scizor
# 232   Mega Heracross
# 248    Mega Houndoom
# 268   Mega Tyranitar
# 275    Mega Sceptile
# 279    Mega Blaziken
# 283    Mega Swampert
# 306   Mega Gardevoir
# 327     Mega Sableye
# 329      Mega Mawile
# 333      Mega Aggron
# 336    Mega Medicham
# 339   Mega Manectric
# 349    Mega Sharpedo
# 354    Mega Camerupt
# 366     Mega Altaria
# 387     Mega Banette
# 393       Mega Absol
# 397      Mega Glalie
# 409   Mega Salamence
# 413   Mega Metagross
# 418      Mega Latias
# 420      Mega Latios
# 426    Mega Rayquaza
# ...

# %%
pokemon
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      2              Ivysaur    Grass  Poison    405  60      62       63
# 2      3             Venusaur    Grass  Poison    525  80      82       83
# 3      3                  NaN    Grass  Poison    625  80     100      123
# 4      4           Charmander     Fire     NaN    309  39      52       43
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy    600  50     100      150
# 796  719                  NaN     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

# %%
pokemon['Name'].replace(re.compile('.*(Mega \w*)'), 'test', inplace=True)

# %%
pokemon['Name']
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3                     test
# 4               Charmander
#               ...
# 795                Diancie
# 796                   test
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
# Name: Name, Length: 800, dtype: object

# %%
p = re.compile(".*(Mega \w*)")

# %%
pokemon['Name'] = pokemon['Name'].apply(lambda s: p.search(s).group(1) if p.search(s) else s)

# %%
pokemon
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      2              Ivysaur    Grass  Poison    405  60      62       63
# 2      3             Venusaur    Grass  Poison    525  80      82       83
# 3      3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4           Charmander     Fire     NaN    309  39      52       43
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy    600  50     100      150
# 796  719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
